# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr,spearmanr
orig_rankings = np.array([0.590164306133055,0.649290395668602,0.652942936208706,0.647184483742267,0.600769184861427,\
                           0.649696268320798, 0.5994201374950169,0.647529319500711,\
                           0.6300454561362,0.6487250234464327,0.643817731132111,0.647786678981121,0.625850319733945,\
                           0.656534260134841,0.629964850307006,0.648764305659868, 0.589181267604318])
sorted_indices = np.argsort(orig_rankings)
task_list = np.array([ 'autoencoder','class_1000', 'class_places','curvature', 'edge2d', 'edge3d',\
                         'keypoint2d', 'keypoint3d','reshade', 'rgb2depth', 'rgb2mist', 'rgb2sfnorm','room_layout' , \
                         'segment25d', 'segment2d', 'segmentsemantic','vanishing_point'])

# %%
#Taskonomy_5000
lap_cka = np.array([0.2895333362536505, 0.368343203746126, 0.3890745564054426, 0.4936771584567602, 0.33484041131493963, 0.46226226650992996, 0.2500481282095301, 0.435911422201637, 0.4411071877442293, 0.423569839036666, 0.4186087827294782, 0.4217756407003788, 0.3942319655857498, 0.4095285840013982, 0.30257702850223694, 0.4486188965753085, 0.20658723953987995])
rbf_cka = np.array([0.26715168260622585, 0.3191270711813704, 0.35779391231795626, 0.44094378010571006, 0.2891390365321295, 0.4178304634410848, 0.24318457624600617, 0.39967446323171474, 0.39065519692267997, 0.3738301295310959, 0.36762370872242606, 0.3770537829213784, 0.3023629082975726, 0.3710285147200464, 0.28388691241633823, 0.32495779346457976, 0.18468964007106384])
cosine_cka = np.array([0.27953168858528066, 0.3232567181303806, 0.3349889340312424, 0.46002515276293116, 0.3109810754378188, 0.42910503741569583, 0.2730664041836418, 0.41342477832170527, 0.4065392698750937, 0.38776880087111054, 0.3849287176160527, 0.40042266511546704, 0.3560258877059364, 0.36175876519185146, 0.27838104353635884, 0.4156193981890799, 0.2221178146576786])

plt.plot(task_list[sorted_indices],lap_cka[sorted_indices],label='lap_cka')
plt.plot(task_list[sorted_indices],rbf_cka[sorted_indices],label='rbf_cka')
plt.plot(task_list[sorted_indices],cosine_cka[sorted_indices],label='cosine_cka')
plt.plot(task_list[sorted_indices],orig_rankings[sorted_indices],label='orig_rankings')
plt.xticks(rotation=90)
   
plt.legend(loc='upper right')
print("------------------------------------------------------------------")
pearson_correlation,_ = pearsonr(lap_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = pearsonr(rbf_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = pearsonr(cosine_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
print("------------------------------------------------------------------")
pearson_correlation,_ = spearmanr(lap_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = spearmanr(rbf_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = spearmanr(cosine_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
# Out:
# ------------------------------------------------------------------
# 0.8271946412179573
# 0.8136613405410685
# 0.7538096175918961
# ------------------------------------------------------------------
# 0.5637254901960785
# 0.6151960784313726
# 0.5588235294117647

# %%
#Pascal_5000
lap_cka = np.array([0.14386517285075126, 0.30403863398006664, 0.283460951006417, 0.23341284090757777, 0.07957582225150737, 0.20813051684083558, 0.11686666864750604, 0.2255946579894853, 0.2435435630230106, 0.21112887301190808, 0.275079616898746, 0.19049092485892088, 0.15423589143492908, 0.3002333975029988, 0.14965635891220377, 0.23670866579869532, 0.07937572507809966])
rbf_cka = np.array([0.11660879119143513, 0.23507427677593937, 0.24008182178306772, 0.15121984835918645, 0.06194922219985964, 0.17040910135607143, 0.09463754385379967, 0.21482433733442102, 0.22153926751682815, 0.17983888673159198, 0.22827122864523847, 0.1775035318522713, 0.12966536054104508, 0.24202703115712187, 0.12816344103024044, 0.18805555905072913, 0.048485598511954775])
cosine_cka = np.array([0.13698714677864393, 0.27674975908226057, 0.2613135096480894, 0.23118595471047185, 0.06366851717362819, 0.19444503613803163, 0.10577745095273225, 0.2271666421846569, 0.23947681757548014, 0.20095933040838695, 0.2603855584477644, 0.19065909602072936, 0.14910915951862347, 0.2746903365397911, 0.1337698716437039, 0.21425382896252756, 0.08393050883864246])

plt.plot(task_list[sorted_indices],lap_cka[sorted_indices],label='lap_cka')
plt.plot(task_list[sorted_indices],rbf_cka[sorted_indices],label='rbf_cka')
plt.plot(task_list[sorted_indices],cosine_cka[sorted_indices],label='cosine_cka')
plt.plot(task_list[sorted_indices],orig_rankings[sorted_indices],label='orig_rankings')
plt.xticks(rotation=90)
   
plt.legend(loc='upper right')
print("------------------------------------------------------------------")
pearson_correlation,_ = pearsonr(lap_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = pearsonr(rbf_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = pearsonr(cosine_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
print("------------------------------------------------------------------")
pearson_correlation,_ = spearmanr(lap_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = spearmanr(rbf_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = spearmanr(cosine_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
# Out:
# ------------------------------------------------------------------
# 0.8516568040415322
# 0.8469887512625617
# 0.851771164132407
# ------------------------------------------------------------------
# 0.7892156862745099
# 0.8137254901960784
# 0.7549019607843138

# %%
#nyuv2
lap_cka = np.array([0.07463054558667936, 0.25212757267999913, 0.2265186376603879, 0.31367523104887135, 0.14891741637341163, 0.31291629014633743, 0.11059287740583051, 0.3013503559029497, 0.3271269991375003, 0.31908481853067333, 0.3190297508525664, 0.3066246754932194, 0.2329946921055883, 0.2583526629201954, 0.12295229929185712, 0.29281179494817516, 0.09078427160185047])
rbf_cka = np.array([0.056223827808354186, 0.18574132411893496, 0.19172062178644858, 0.24332267624010548, 0.11451667096013675, 0.25212130184941617, 0.08756256722465908, 0.23950786023732654, 0.2704954813687918, 0.24237704676721325, 0.2517963595141067, 0.24469508920597338, 0.14205601173498478, 0.21082444270757206, 0.10076401939615463, 0.21413289875969557, 0.08106602033561562])
cosine_cka = np.array([0.07584066976246157, 0.22933623919638257, 0.2093246693784028, 0.28450177684832917, 0.12880146915992932, 0.29185190187997556, 0.10659173896105698, 0.28370854503471266, 0.3069250334653632, 0.29536475162052583, 0.2917544761667597, 0.29003840438242934, 0.2101446010695923, 0.23171377063617932, 0.11663340390941508, 0.2767871354355078, 0.09238406230137479])
plt.plot(task_list[sorted_indices],lap_cka[sorted_indices],label='lap_cka')
plt.plot(task_list[sorted_indices],rbf_cka[sorted_indices],label='rbf_cka')
plt.plot(task_list[sorted_indices],cosine_cka[sorted_indices],label='cosine_cka')
plt.plot(task_list[sorted_indices],orig_rankings[sorted_indices],label='orig_rankings')
plt.xticks(rotation=90)
   
plt.legend(loc='upper right')
print("------------------------------------------------------------------")
pearson_correlation,_ = pearsonr(lap_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = pearsonr(rbf_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = pearsonr(cosine_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
print("------------------------------------------------------------------")
pearson_correlation,_ = spearmanr(lap_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = spearmanr(rbf_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
pearson_correlation,_ = spearmanr(cosine_cka[sorted_indices], orig_rankings[sorted_indices])
print(pearson_correlation)
# Out:
# ------------------------------------------------------------------
# 0.8430985782461844
# 0.8373833674835285
# 0.8350139660851587
# ------------------------------------------------------------------
# 0.49019607843137264
# 0.5465686274509804
# 0.5269607843137256
